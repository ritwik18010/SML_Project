# %%
dtypes = {
        'MachineIdentifier':                                    'category',
        'ProductName':                                          'category',
        'EngineVersion':                                        'category',
        'AppVersion':                                           'category',
        'AvSigVersion':                                         'category',
        'IsBeta':                                               'int8',
        'RtpStateBitfield':                                     'float16',
        'IsSxsPassiveMode':                                     'int8',
        'DefaultBrowsersIdentifier':                            'float16',
        'AVProductStatesIdentifier':                            'float32',
        'AVProductsInstalled':                                  'float16',
        'AVProductsEnabled':                                    'float16',
        'HasTpm':                                               'int8',
        'CountryIdentifier':                                    'int16',
        'CityIdentifier':                                       'float32',
        'OrganizationIdentifier':                               'float16',
        'GeoNameIdentifier':                                    'float16',
        'LocaleEnglishNameIdentifier':                          'int8',
        'Platform':                                             'category',
        'Processor':                                            'category',
        'OsVer':                                                'category',
        'OsBuild':                                              'int16',
        'OsSuite':                                              'int16',
        'OsPlatformSubRelease':                                 'category',
        'OsBuildLab':                                           'category',
        'SkuEdition':                                           'category',
        'IsProtected':                                          'float16',
        'AutoSampleOptIn':                                      'int8',
        'PuaMode':                                              'category',
        'SMode':                                                'float16',
        'IeVerIdentifier':                                      'float16',
        'SmartScreen':                                          'category',
        'Firewall':                                             'float16',
        'UacLuaenable':                                         'float32',
        'Census_MDC2FormFactor':                                'category',
        'Census_DeviceFamily':                                  'category',
        'Census_OEMNameIdentifier':                             'float16',
        'Census_OEMModelIdentifier':                            'float32',
        'Census_ProcessorCoreCount':                            'float16',
        'Census_ProcessorManufacturerIdentifier':               'float16',
        'Census_ProcessorModelIdentifier':                      'float16',
        'Census_ProcessorClass':                                'category',
        'Census_PrimaryDiskTotalCapacity':                      'float32',
        'Census_PrimaryDiskTypeName':                           'category',
        'Census_SystemVolumeTotalCapacity':                     'float32',
        'Census_HasOpticalDiskDrive':                           'int8',
        'Census_TotalPhysicalRAM':                              'float32',
        'Census_ChassisTypeName':                               'category',
        'Census_InternalPrimaryDiagonalDisplaySizeInInches':    'float16',
        'Census_InternalPrimaryDisplayResolutionHorizontal':    'float16',
        'Census_InternalPrimaryDisplayResolutionVertical':      'float16',
        'Census_PowerPlatformRoleName':                         'category',
        'Census_InternalBatteryType':                           'category',
        'Census_InternalBatteryNumberOfCharges':                'float32',
        'Census_OSVersion':                                     'category',
        'Census_OSArchitecture':                                'category',
        'Census_OSBranch':                                      'category',
        'Census_OSBuildNumber':                                 'int16',
        'Census_OSBuildRevision':                               'int32',
        'Census_OSEdition':                                     'category',
        'Census_OSSkuName':                                     'category',
        'Census_OSInstallTypeName':                             'category',
        'Census_OSInstallLanguageIdentifier':                   'float16',
        'Census_OSUILocaleIdentifier':                          'int16',
        'Census_OSWUAutoUpdateOptionsName':                     'category',
        'Census_IsPortableOperatingSystem':                     'int8',
        'Census_GenuineStateName':                              'category',
        'Census_ActivationChannel':                             'category',
        'Census_IsFlightingInternal':                           'float16',
        'Census_IsFlightsDisabled':                             'float16',
        'Census_FlightRing':                                    'category',
        'Census_ThresholdOptIn':                                'float16',
        'Census_FirmwareManufacturerIdentifier':                'float16',
        'Census_FirmwareVersionIdentifier':                     'float32',
        'Census_IsSecureBootEnabled':                           'int8',
        'Census_IsWIMBootEnabled':                              'float16',
        'Census_IsVirtualDevice':                               'float16',
        'Census_IsTouchEnabled':                                'int8',
        'Census_IsPenCapable':                                  'int8',
        'Census_IsAlwaysOnAlwaysConnectedCapable':              'float16',
        'Wdft_IsGamer':                                         'float16',
        'Wdft_RegionIdentifier':                                'float16',
        'HasDetections':                                        'int8'
        }

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
df=pd.read_csv('gdrive/My Drive/final_data.csv',dtype=dtypes,nrows=15000000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-61e6b30bf80a> in <module>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('gdrive/My Drive/final_data.csv',dtype=dtypes,nrows=15000000)
#
# NameError: name 'dtypes' is not defined

# %%
train_data=df

# %%
Categorical_Features = list(train_data.loc[:, train_data.dtypes =="category"].columns)
Numerical_Features = list(train_data.loc[:, train_data.dtypes !="category"].columns)

# %%
Train=train_data

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

def MultiLabelEncoder(columnlist,dataframe):
    for i in columnlist:
        print(i)
        labelencoder_X=LabelEncoder()
        dataframe[i]=labelencoder_X.fit_transform(dataframe[i].astype(str))
MultiLabelEncoder(Categorical_Features, Train)

# %%
Train

# %%
Label=Train['HasDetections']
Data=Train.drop(['MachineIdentifier','HasDetections'],axis=1)

# %%
Data=Data.fillna(0)

# %%
Data

# %%
# from sklearn.decomposition import PCA
# pca = PCA(n_components=3, svd_solver='arpack')
# pca.fit(Data)
# PCA_Data=X = pca.transform(Data)

# %%
# PCA_Data=pd.DataFrame(PCA_Data)

# %%
# PCA_Data

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(8, 6))
ax = Axes3D(fig, elev=-150, azim=110)
ax.scatter(PCA_Data.iloc[:, 0], PCA_Data.iloc[:, 1], PCA_Data.iloc[:, 2],  cmap=plt.cm.nipy_spectral,
           edgecolor='k',s=40)

# %%
import matplotlib.pyplot as plt
c=['Red',"blue",'green']
#for i in range(3):
    #y=PCA_Data[inbuilt_pca['label']==str(i+1)]
plt.scatter(PCA_Data[0],PCA_Data[1],color=c[1],alpha=0.5)
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
Label

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

X_train, X_test, y_train, y_test = train_test_split(Data, Label, test_size=(1/3))
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

# %%
Training_Data=pd.DataFrame(X_train)
Training_Data.index=range(len(Training_Data))
Training_Label=pd.DataFrame(y_train)
Training_Label.index=range(len(Training_Label))
Testing_Data=pd.DataFrame(X_test)
Testing_Data.index=range(len(Testing_Data))
Testing_Label=pd.DataFrame(y_test)
Testing_Label.index=range(len(Testing_Label))

# %%
Training=pd.concat([Training_Data,Training_Label],axis=1)

# %%
#sklearn.model_selection.cross_validate()
import seaborn as sns
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

# %%
# kfold = model_selection.KFold(n_splits=5, random_state=7)
# model = LogisticRegression()
# results = model_selection.cross_val_score(model, Training_Data, Training_Label, cv=kfold)
# print("Accuracy: Final mean:%.3f%%, Final standard deviation:(%.3f%%)" % (results.mean()*100.0, results.std()*100.0))
# print('Accuracies from each of the 5 folds using kfold:',results)
# print("Variance of kfold accuracies:",results.var())

# %%
import math
def divide_chunks(l, n): 
    for i in range(0, len(l), n):  
        yield l[i:i + n] 
n = math.ceil(len(Training_Data)/5)
train_fold= list(divide_chunks((Training_Data.values.tolist()), n)) 
newlabel = list(divide_chunks((Training_Label.values), n))

# %%
print(len(train_fold[0]))
print(len(newlabel[0]))

# %%
def accuracy(predicted,actual):
    c=0
    for i in range(len(predicted)):
        if(predicted[i]==actual[i]):
            c=c+1
    s=c/len(predicted)
    return s

# %%
from sklearn.naive_bayes import GaussianNB
def Classifier(train,trainlabel,test):
        clf = GaussianNB()
        clf.fit(train,trainlabel)
        predicted=clf.predict(test)
        #posterior=clf.predict_log_proba(test)
        return predicted

# %%
# import seaborn as sns
# def ConfusionMatrix(Actual,Predicted):
#     confusion_matrix=np.zeros((2,2))
#     print(Predicted)
#     for i in range(len(Actual)):
#         confusion_matrix[Actual[i]][Predicted[i]]=confusion_matrix[Actual[i]][Predicted[i]]+1
#     return confusion_matrix

# %%
print((newlabel[0]))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
def Kfold(train_fold,newlabel,testing,testinglabel):
    a=[]
    besttrainingset=[]
    besttrainlabel=[]
    for i in range(5):
        test1=[]
        train1=[]
        actual_test1=[]
        actual_train1=[]
        for j in range(5):
            if(i==j):
                test1=train_fold[i]
                actual_test1=newlabel[i]
            else:
                train1 = train1+train_fold[j]
                #actual_train1 = actual_train1+newlabel[j]
                actual_train1.extend(newlabel[j])
                
        test1=pd.DataFrame(test1)
        besttrainingset.append(train1)
        besttrainlabel.append(actual_train1)
        predicted=Classifier(train1,actual_train1,test1)
        Accuracy=accuracy(predicted,actual_test1)
        print(Accuracy)
        a.append(Accuracy)
    mean=np.sum(a)/5
    std=np.std(a)
    print("mean and Standard deviation",mean,std)
    max_accuracy=-100
    index=-1
    for i in range(len(a)):
        if(max_accuracy<a[i]):
            max_accuracy=a[i]
            index=i
    print(max_accuracy)
    print(index)
    TrainingSet=besttrainingset[index]
    TrainingLabel=besttrainlabel[index]
    predicted_test=Classifier(TrainingSet,TrainingLabel,testing)
    y= confusion_matrix(testinglabel,predicted_test)
    sns.heatmap(y,annot=True)
    tn, fp, fn, tp=y.ravel()
    Accuracy=(tn+tp)/(tn+tp+fn+fp)
    print(Accuracy)
#     from sklearn import metrics
#     metrics.roc_curve(testinglabel,predicted_test)
Kfold(train_fold,newlabel,Testing_Data,Testing_Label)

# %%
from sklearn import metrics
metrics.roc_curve(y, scores)
